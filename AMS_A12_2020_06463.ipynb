# %% [markdown]
# ## Pengambilan Data

# %%
import pandas as pd
import time
import tweepy
import numpy as np

def twitter_config():
    """
    Fungsi utilitas untuk mengkonfigurasi konsumsi file API Twitter dengan␣
    ,!kunci yang disediakan.
    """
    # Otentikasi dan akses menggunakan kunci:
    auth = tweepy.OAuthHandler("Ow2TUoODybHnty5jOWz82xY7J",
    "p7Ff6AqkccFvQCIKi542yRETvUh3CMYfwq15JVbWpab5ZqF6V3")
    auth.set_access_token("1572073503544967168-cGj4aRIj8iq983O1WCkF1cuE9r81xV",
    "eHKgEFA6IrWHoONQ27Ub7Kmz6IpHJKYkDicUL4NPuaFTh")
    # Kembalikan akses ke API:
    api = tweepy.API(auth)
    try:
        api.verify_credentials()
        print("Authentication OK")
    except:
        print("Error during authentication")
    return api

# buat extractor object
extractor = twitter_config()

tweets = extractor.user_timeline(screen_name="asumsico", count=100)
print("Tweets terambil: {}.\n".format(len(tweets)))


print("5 tweet teratas:\n")
for tweet in tweets[:5]:
    print(tweet.text)
    print()
# Out:
# Authentication OK
# Tweets terambil: 100.
#
# 5 tweet teratas:
#
# Oktober 2019 Pak Bas bersama PM Belanda Mark Rutte foto bareng karena sama-sama pake handphone jadul. Kayaknya itu… https://t.co/yh2bogP3xD
#
# Pak Bas pake Nokia?? https://t.co/73N7Yk7nUg
#
# Transportasi umum di Jakarta dari masa ke masa selalu berkembang, tapi apakah sudah oke dan cukup memadai?
#
# Bersama… https://t.co/jqxF0A3Apy
#
# Majelis Hakim Pengadilan Negeri Jakarta Selatan menolak nota keberatan atau eksepsi Ferdy Sambo atas dakwaan dugaan… https://t.co/F0PBPQXcVe
#
# Seorang pecinta sepak bola, Santiago Sanchez hilang di Iran. Ia dilaporkan menghilang dalam perjalanannya dari Madr… https://t.co/CzuckjdE0V

# %%
# Kita dapat membuat kerangka data sebagai berikut:
dataset = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# Kami membuat tampilan kerangka data:
display(dataset.head(10))

dataset.to_csv('Data Set Asumsi.csv',sep=';')
# Out:
#                                               Tweets
# 0  Oktober 2019 Pak Bas bersama PM Belanda Mark R...
# 1       Pak Bas pake Nokia?? https://t.co/73N7Yk7nUg
# 2  Transportasi umum di Jakarta dari masa ke masa...
# 3  Majelis Hakim Pengadilan Negeri Jakarta Selata...
# 4  Seorang pecinta sepak bola, Santiago Sanchez h...
# 5  Sepakat atau enggak dengan penilaian BEM UI ya...
# 6  Dalam melancarkan aksinya, sang peretas turut ...
# 7  Ketinggian air di banjir Jakarta Timur mencapa...
# 8  Serangan udara tersebut menewaskan 80 orang, t...
# 9  Ia mengklarifikasi pernyataan kuasa hukum Brig...

# %% [markdown]
# ## Pengolahan Data Set

# %%
import re
import string
import time
from copy import deepcopy
import pandas as pd

# %% [markdown]
# ## Membaca Data Set

# %%
df = pd.read_csv('Data_set.csv', sep=';')
df.head()
# Out:
#    Column1                                             Tweets  label
# 0        0  Transportasi umum di Jakarta dari masa ke masa...      0
# 1        1  Majelis Hakim Pengadilan Negeri Jakarta Selata...      1
# 2        2  Seorang pecinta sepak bola, Santiago Sanchez h...      0
# 3        3  Sepakat atau enggak dengan penilaian BEM UI ya...      1
# 4        4  Dalam melancarkan aksinya, sang peretas turut ...      0

# %% [markdown]
# ## Instalasi Package Ekpharasis

# %%
# !pip install ekphrasis
# Out:
# Requirement already satisfied: ekphrasis in c:\users\adam\anaconda3\lib\site-packages (0.5.4)
# Requirement already satisfied: ujson in c:\users\adam\anaconda3\lib\site-packages (from ekphrasis) (5.1.0)
# Requirement already satisfied: nltk in c:\users\adam\anaconda3\lib\site-packages (from ekphrasis) (3.7)
# Requirement already satisfied: colorama in c:\users\adam\anaconda3\lib\site-packages (from ekphrasis) (0.4.4)
# Requirement already satisfied: tqdm in c:\users\adam\anaconda3\lib\site-packages (from ekphrasis) (4.64.0)
# Requirement already satisfied: termcolor in c:\users\adam\anaconda3\lib\site-packages (from ekphrasis) (2.0.1)
# Requirement already satisfied: matplotlib in c:\users\adam\anaconda3\lib\site-packages (from ekphrasis) (3.5.1)
# Requirement already satisfied: numpy in c:\users\adam\anaconda3\lib\site-packages (from ekphrasis) (1.21.5)
# Requirement already satisfied: ftfy in c:\users\adam\anaconda3\lib\site-packages (from ekphrasis) (6.1.1)
# Requirement already satisfied: wcwidth>=0.2.5 in c:\users\adam\anaconda3\lib\site-packages (from ftfy->ekphrasis) (0.2.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\adam\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->ekphrasis) (1.16.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\adam\anaconda3\lib\site-packages (from nltk->ekphrasis) (2022.3.15)
# Requirement already satisfied: click in c:\users\adam\anaconda3\lib\site-packages (from nltk->ekphrasis) (8.0.4)
# Requirement already satisfied: joblib in c:\users\adam\anaconda3\lib\site-packages (from nltk->ekphrasis) (1.1.0)

# %%
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['email', 'percent', 'money', 'phone', 'user',
        'time', 'date', 'number'],
    # terms that will be annotated
    #annotate={"hashtag", "allcaps", "elongated", "repeated",'emphasis', 'censored'},
    annotate={"hashtag"},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated words
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)
# Out:
# C:\Users\Adam\anaconda3\lib\site-packages\ekphrasis\classes\tokenizer.py:225: FutureWarning: Possible nested set at position 2190
#   self.tok = re.compile(r"({})".format("|".join(pipeline)))
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...
# C:\Users\Adam\anaconda3\lib\site-packages\ekphrasis\classes\exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in

# %% [markdown]
# ## Membuat Fungsi

# %%
# panggil ekphrasis

def bersih_data(text):
    return " ".join(text_processor.pre_process_doc(text))
# fungsi dari AMS 01-03. silakan cek bagaimana saya merubah menjadi fungsi

def non_ascii(text):
    return text.encode('ascii', 'replace').decode('ascii')

def remove_space_alzami(text):
    return " ".join(text.split())

def remove_emoji_alzami(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

def remove_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

def remove_tab2(text):
    return re.sub('\s+',' ',text)

def remove_rt(text):
    return text.replace('RT'," ")

def remove_mention(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

def remove_incomplete_url(text):
    return text.replace("http://", " ").replace("https://", " ")

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def change_stripe(text):
    return text.replace('-'," ")

def lower(text):
    return text.lower()

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def lower(text):
    return text.lower()

def remove_whitespace_LT(text):
    return text.strip()

def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") # don't remove hyphens
    pattern = r"[{}]".format(remove) # create the pattern
    return re.sub(pattern, "", text) 
# hapus untuk <>
def remove_number_eks(text):
    return text.replace('<number>'," ")

def remove_angka(text):
    return re.sub(r"\d+", "", text) 

def remove_URL_eks(text):
    return text.replace('URL'," ").replace('url'," ")

def space_punctuation(text):
    return re.sub('(?<! )(?=[.,!?()])|(?<=[.,!?()])(?! )', r' ', text)

# %% [markdown]
# ## Memanggil Fungsi

# %%
i = 0
final_string = []
s = ""
for text in df['Tweets'].values:
    filteredSentence = []
    EachReviewText = ""
    proc = remove_rt(text)
    proc = lower(proc)
    proc = change_stripe(proc)
    proc = remove_emoji_alzami(proc)
    proc = remove_tab(proc)
    proc = remove_tab2(proc)
    proc = non_ascii(proc)
    proc = remove_incomplete_url(proc)
    proc = remove_excessive_dot(proc)
    proc = remove_whitespace_LT(proc)
    proc = remove_whitespace_multiple(proc)
    proc = remove_single_char(proc)
    proc = space_punctuation(proc)
    proc = remove_punctuation(proc)
    proc = remove_space_alzami(proc)
    proc = bersih_data(proc)
    proc = remove_number_eks(proc)
    proc = remove_angka(proc) 
    proc = remove_URL_eks(proc)
    EachReviewText = proc
    final_string.append(EachReviewText)

# %%
df["step01"] = final_string
df.head(10)
# Out:
#    Column1                                             Tweets  label  \
# 0        0  Transportasi umum di Jakarta dari masa ke masa...      0
# 1        1  Majelis Hakim Pengadilan Negeri Jakarta Selata...      1
# 2        2  Seorang pecinta sepak bola, Santiago Sanchez h...      0
# 3        3  Sepakat atau enggak dengan penilaian BEM UI ya...      1
# 4        4  Dalam melancarkan aksinya, sang peretas turut ...      0
# 5        5  Ketinggian air di banjir Jakarta Timur mencapa...      0
# 6        6  Serangan udara tersebut menewaskan 80 orang, t...      0
# 7        7  Ia mengklarifikasi pernyataan kuasa hukum Brig...      1
# 8        8  Hotman Paris Hutapea, Pengacara Irjen Teddy Mi...      0
# 9        9  Kajari Serang Freddy D. Simandjuntak mengataka...      0
#
#                                               step01
# 0  transportasi umum di jakarta dari masa ke masa...
# 1  majelis hakim pengadilan negeri jakarta selata...
# 2  seorang pecinta sepak bola santiago sanchez hi...
# 3  sepakat atau enggak dengan penilaian bem ui ya...
# 4  dalam melancarkan aksinya sang peretas turut m...
# 5  ketinggian air di banjir jakarta timur mencapa...
# 6  serangan udara tersebut menewaskan   orang ter...
# 7  ia mengklarifikasi pernyataan kuasa hukum brig...
# 8  hotman paris hutapea pengacara irjen teddy min...
# 9  kajari serang freddy simandjuntak mengatakan p...

# %% [markdown]
# ## Menghapus Data yang kosong

# %%
df.info()
df_hapus = df[~df['step01'].str.contains(" ")]
df_hapus.info()
df_hapus.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Column1  100 non-null    int64
#  1   Tweets   100 non-null    object
#  2   label    100 non-null    int64
#  3   step01   100 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 3.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 25 to 77
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Column1  2 non-null      int64
#  1   Tweets   2 non-null      object
#  2   label    2 non-null      int64
#  3   step01   2 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 80.0+ bytes
#     Column1                   Tweets  label       step01
# 25       25  https://t.co/HJz44MrrEP      0   cohjzmrrep
# 77       77  https://t.co/g9fTNvGVrE      0  cogftnvgvre

# %%
df_new = df[~df.isin(df_hapus)].dropna()
df_new.info()
df_new
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Column1  98 non-null     float64
#  1   Tweets   98 non-null     object
#  2   label    98 non-null     float64
#  3   step01   98 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 3.8+ KB
#     Column1                                             Tweets  label  \
# 0       0.0  Transportasi umum di Jakarta dari masa ke masa...    0.0
# 1       1.0  Majelis Hakim Pengadilan Negeri Jakarta Selata...    1.0
# 2       2.0  Seorang pecinta sepak bola, Santiago Sanchez h...    0.0
# 3       3.0  Sepakat atau enggak dengan penilaian BEM UI ya...    1.0
# 4       4.0  Dalam melancarkan aksinya, sang peretas turut ...    0.0
# ..      ...                                                ...    ...
# 95     95.0  Maskapai Korean Air itu tergelincir dari landa...    0.0
# 96     96.0  Korban meninggal dunia tersebut bernama FDK (2...    0.0
# 97     97.0  Australia menyebut gugusan Pulau Pasir sebagai...    0.0
# 98     98.0  Pelaku tertangkap pada Minggu sore di kawasan ...    0.0
# 99     99.0  Kepala BPOM Penny Lukito menjelaskan, masih ad...    0.0
#
#                                                step01
# 0   transportasi umum di jakarta dari masa ke masa...
# 1   majelis hakim pengadilan negeri jakarta selata...
# 2   seorang pecinta sepak bola santiago sanchez hi...
# 3   sepakat atau enggak dengan penilaian bem ui ya...
# 4   dalam melancarkan aksinya sang peretas turut m...
# ..                                                ...
# 95  maskapai korean air itu tergelincir dari landa...
# 96  korban meninggal dunia tersebut bernama fdk   ...
# 97  australia menyebut gugusan pulau pasir sebagai...
# 98  pelaku tertangkap pada minggu sore di kawasan ...
# 99  kepala bpom penny lukito menjelaskan masih ada...
#
# [98 rows x 4 columns]

# %% [markdown]
# ## Normalisasi Kata Slang

# %%
# token
import nltk
from nltk.tokenize import word_tokenize

# %%
def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
df_new['tokens'] = df['step01'].apply(word_tokenize_wrapper)

# %%
df_new.head(10)
# Out:
#    Column1                                             Tweets  label  \
# 0      0.0  Transportasi umum di Jakarta dari masa ke masa...    0.0
# 1      1.0  Majelis Hakim Pengadilan Negeri Jakarta Selata...    1.0
# 2      2.0  Seorang pecinta sepak bola, Santiago Sanchez h...    0.0
# 3      3.0  Sepakat atau enggak dengan penilaian BEM UI ya...    1.0
# 4      4.0  Dalam melancarkan aksinya, sang peretas turut ...    0.0
# 5      5.0  Ketinggian air di banjir Jakarta Timur mencapa...    0.0
# 6      6.0  Serangan udara tersebut menewaskan 80 orang, t...    0.0
# 7      7.0  Ia mengklarifikasi pernyataan kuasa hukum Brig...    1.0
# 8      8.0  Hotman Paris Hutapea, Pengacara Irjen Teddy Mi...    0.0
# 9      9.0  Kajari Serang Freddy D. Simandjuntak mengataka...    0.0
#
#                                               step01  \
# 0  transportasi umum di jakarta dari masa ke masa...
# 1  majelis hakim pengadilan negeri jakarta selata...
# 2  seorang pecinta sepak bola santiago sanchez hi...
# 3  sepakat atau enggak dengan penilaian bem ui ya...
# 4  dalam melancarkan aksinya sang peretas turut m...
# 5  ketinggian air di banjir jakarta timur mencapa...
# 6  serangan udara tersebut menewaskan   orang ter...
# 7  ia mengklarifikasi pernyataan kuasa hukum brig...
# 8  hotman paris hutapea pengacara irjen teddy min...
# 9  kajari serang freddy simandjuntak mengatakan p...
#
#                                               tokens
# 0  [transportasi, umum, di, jakarta, dari, masa, ...
# 1  [majelis, hakim, pengadilan, negeri, jakarta, ...
# 2  [seorang, pecinta, sepak, bola, santiago, sanc...
# 3  [sepakat, atau, enggak, dengan, penilaian, bem...
# 4  [dalam, melancarkan, aksinya, sang, peretas, t...
# 5  [ketinggian, air, di, banjir, jakarta, timur, ...
# 6  [serangan, udara, tersebut, menewaskan, orang,...
# 7  [ia, mengklarifikasi, pernyataan, kuasa, hukum...
# 8  [hotman, paris, hutapea, pengacara, irjen, ted...
# 9  [kajari, serang, freddy, simandjuntak, mengata...

# %% [markdown]
# ## Clean Kamus

# %%
normalized_word = pd.read_csv('kamus_clean.csv')

# %%
normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]

# %%
df_new['final_tokens'] = df_new['tokens'].apply(normalized_term)

# %%
i=0
final_string_tokens = []
for text in df_new['final_tokens'].values:
    EachReviewText = ""
    EachReviewText = ' '.join(text)
    final_string_tokens.append(EachReviewText)

# %%
df_new["step02"] = final_string_tokens
df_new.head(10)
# Out:
#    Column1                                             Tweets  label  \
# 0      0.0  Transportasi umum di Jakarta dari masa ke masa...    0.0
# 1      1.0  Majelis Hakim Pengadilan Negeri Jakarta Selata...    1.0
# 2      2.0  Seorang pecinta sepak bola, Santiago Sanchez h...    0.0
# 3      3.0  Sepakat atau enggak dengan penilaian BEM UI ya...    1.0
# 4      4.0  Dalam melancarkan aksinya, sang peretas turut ...    0.0
# 5      5.0  Ketinggian air di banjir Jakarta Timur mencapa...    0.0
# 6      6.0  Serangan udara tersebut menewaskan 80 orang, t...    0.0
# 7      7.0  Ia mengklarifikasi pernyataan kuasa hukum Brig...    1.0
# 8      8.0  Hotman Paris Hutapea, Pengacara Irjen Teddy Mi...    0.0
# 9      9.0  Kajari Serang Freddy D. Simandjuntak mengataka...    0.0
#
#                                               step01  \
# 0  transportasi umum di jakarta dari masa ke masa...
# 1  majelis hakim pengadilan negeri jakarta selata...
# 2  seorang pecinta sepak bola santiago sanchez hi...
# 3  sepakat atau enggak dengan penilaian bem ui ya...
# 4  dalam melancarkan aksinya sang peretas turut m...
# 5  ketinggian air di banjir jakarta timur mencapa...
# 6  serangan udara tersebut menewaskan   orang ter...
# 7  ia mengklarifikasi pernyataan kuasa hukum brig...
# 8  hotman paris hutapea pengacara irjen teddy min...
# 9  kajari serang freddy simandjuntak mengatakan p...
#
#                                               tokens  \
# 0  [transportasi, umum, di, jakarta, dari, masa, ...
# 1  [majelis, hakim, pengadilan, negeri, jakarta, ...
# 2  [seorang, pecinta, sepak, bola, santiago, sanc...
# 3  [sepakat, atau, enggak, dengan, penilaian, bem...
# 4  [dalam, melancarkan, aksinya, sang, peretas, t...
# 5  [ketinggian, air, di, banjir, jakarta, timur, ...
# 6  [serangan, udara, tersebut, menewaskan, orang,...
# 7  [ia, mengklarifikasi, pernyataan, kuasa, hukum...
# 8  [hotman, paris, hutapea, pengacara, irjen, ted...
# 9  [kajari, serang, freddy, simandjuntak, mengata...
#
#                                         final_tokens  \
# 0  [transportasi, umum, di, jakarta, dari, masa, ...
# 1  [majelis, hakim, pengadilan, negeri, jakarta, ...
# 2  [seorang, pecinta, sepak, bola, santiago, sanc...
# 3  [sepakat, atau, enggak, dengan, penilaian, bem...
# 4  [dalam, melancarkan, aksinya, sang, peretas, t...
# 5  [ketinggian, air, di, banjir, jakarta, timur, ...
# 6  [serangan, udara, tersebut, menewaskan, orang,...
# 7  [ia, mengklarifikasi, pernyataan, kuasa, hukum...
# 8  [hotman, paris, hutapea, pengacara, irjen, ted...
# 9  [kajari, serang, freddy, simandjuntak, mengata...
#
#                                               step02
# 0  transportasi umum di jakarta dari masa ke masa...
# 1  majelis hakim pengadilan negeri jakarta selata...
# 2  seorang pecinta sepak bola santiago sanchez hi...
# 3  sepakat atau enggak dengan penilaian bem ui ya...
# 4  dalam melancarkan aksinya sang peretas turut m...
# 5  ketinggian air di banjir jakarta timur mencapa...
# 6  serangan udara tersebut menewaskan orang terma...
# 7  ia mengklarifikasi pernyataan kuasa hukum brig...
# 8  hotman paris hutapea pengacara irjen teddy min...
# 9  kajari serang freddy simandjuntak mengatakan p...

# %%
df_new.to_csv('Data Set Bersih.csv',sep=";")

# %% [markdown]
# # Stemming menggunakan Sastrawi

# %% [markdown]
# ## load sastrawi

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %% [markdown]
# ## stopwords

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
 
factory = StopWordRemoverFactory()

more_stopword = ['sih', 'nya','rt','loh','lah', 'dd', 'mah', 'nye', 'eh', 'ehh', 'ah', 'yang']
 
# Tambahkan Stopword Baru
### Tuliskan perintahnya disini ???

stopwords_sastrawi = factory.create_stop_word_remover()

# %%
df_new['step02'] = df_new['step02'].apply(str)

# %%
df_new.head()
# Out:
#    Column1                                             Tweets  label  \
# 0      0.0  Transportasi umum di Jakarta dari masa ke masa...    0.0
# 1      1.0  Majelis Hakim Pengadilan Negeri Jakarta Selata...    1.0
# 2      2.0  Seorang pecinta sepak bola, Santiago Sanchez h...    0.0
# 3      3.0  Sepakat atau enggak dengan penilaian BEM UI ya...    1.0
# 4      4.0  Dalam melancarkan aksinya, sang peretas turut ...    0.0
#
#                                               step01  \
# 0  transportasi umum di jakarta dari masa ke masa...
# 1  majelis hakim pengadilan negeri jakarta selata...
# 2  seorang pecinta sepak bola santiago sanchez hi...
# 3  sepakat atau enggak dengan penilaian bem ui ya...
# 4  dalam melancarkan aksinya sang peretas turut m...
#
#                                               tokens  \
# 0  [transportasi, umum, di, jakarta, dari, masa, ...
# 1  [majelis, hakim, pengadilan, negeri, jakarta, ...
# 2  [seorang, pecinta, sepak, bola, santiago, sanc...
# 3  [sepakat, atau, enggak, dengan, penilaian, bem...
# 4  [dalam, melancarkan, aksinya, sang, peretas, t...
#
#                                         final_tokens  \
# 0  [transportasi, umum, di, jakarta, dari, masa, ...
# 1  [majelis, hakim, pengadilan, negeri, jakarta, ...
# 2  [seorang, pecinta, sepak, bola, santiago, sanc...
# 3  [sepakat, atau, enggak, dengan, penilaian, bem...
# 4  [dalam, melancarkan, aksinya, sang, peretas, t...
#
#                                               step02
# 0  transportasi umum di jakarta dari masa ke masa...
# 1  majelis hakim pengadilan negeri jakarta selata...
# 2  seorang pecinta sepak bola santiago sanchez hi...
# 3  sepakat atau enggak dengan penilaian bem ui ya...
# 4  dalam melancarkan aksinya sang peretas turut m...

# %%
i=0
final_string = []
s = ""
for sentence in df_new["step02"].values:
    filteredSentence = []
    EachReviewText = ""
    st = stopwords_sastrawi.remove(sentence)
    s = (stemmer.stem(st))
    filteredSentence.append(s)
    
    EachReviewText = ' '.join(filteredSentence)
    final_string.append(EachReviewText)

# %%
df_new.loc[:, ('ProcessedText')] = final_string

# %%
df_new.head()
# Out:
#    Column1                                             Tweets  label  \
# 0      0.0  Transportasi umum di Jakarta dari masa ke masa...    0.0
# 1      1.0  Majelis Hakim Pengadilan Negeri Jakarta Selata...    1.0
# 2      2.0  Seorang pecinta sepak bola, Santiago Sanchez h...    0.0
# 3      3.0  Sepakat atau enggak dengan penilaian BEM UI ya...    1.0
# 4      4.0  Dalam melancarkan aksinya, sang peretas turut ...    0.0
#
#                                               step01  \
# 0  transportasi umum di jakarta dari masa ke masa...
# 1  majelis hakim pengadilan negeri jakarta selata...
# 2  seorang pecinta sepak bola santiago sanchez hi...
# 3  sepakat atau enggak dengan penilaian bem ui ya...
# 4  dalam melancarkan aksinya sang peretas turut m...
#
#                                               tokens  \
# 0  [transportasi, umum, di, jakarta, dari, masa, ...
# 1  [majelis, hakim, pengadilan, negeri, jakarta, ...
# 2  [seorang, pecinta, sepak, bola, santiago, sanc...
# 3  [sepakat, atau, enggak, dengan, penilaian, bem...
# 4  [dalam, melancarkan, aksinya, sang, peretas, t...
#
#                                         final_tokens  \
# 0  [transportasi, umum, di, jakarta, dari, masa, ...
# 1  [majelis, hakim, pengadilan, negeri, jakarta, ...
# 2  [seorang, pecinta, sepak, bola, santiago, sanc...
# 3  [sepakat, atau, enggak, dengan, penilaian, bem...
# 4  [dalam, melancarkan, aksinya, sang, peretas, t...
#
#                                               step02  \
# 0  transportasi umum di jakarta dari masa ke masa...
# 1  majelis hakim pengadilan negeri jakarta selata...
# 2  seorang pecinta sepak bola santiago sanchez hi...
# 3  sepakat atau enggak dengan penilaian bem ui ya...
# 4  dalam melancarkan aksinya sang peretas turut m...
#
#                                        ProcessedText
# 0  transportasi umum jakarta masa masa selalu kem...
# 1  majelis hakim adil negeri jakarta selatan tola...
# 2  orang cinta sepak bola santiago sanchez hilang...
# 3  sepakat enggak nilai bem ui bilang joko widodo...
# 4  lancar aksi sang retas turut bubuh narasi kena...

# %%
df_new.to_csv('Data Set Bersih 2.csv',sep=";")

# %% [markdown]
# ## preprocessing data

# %% [markdown]
# masuk ke tahap machine learning

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## dibagi menjadi feature dan label

# %%
dataset_feature = df_new['ProcessedText']

# %%
dataset_label = df_new['label']

# %% [markdown]
# ## Cek

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset_label.value_counts()
# Out:
# 0.0    81
# 1.0    17
# Name: label, dtype: int64

# %%
dataset_label.value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# 0.0    82.7%
# 1.0    17.3%
# Name: label, dtype: object

# %%
# Visualizing the target variable
plt.figure(figsize=(12,8))
sns.displot(dataset_label, label=f'target, skew: {dataset_label.skew():.2f}')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Kesimpulan:

# %% [markdown]
# # Fitur Ekstraksi menggunakan TF-IDF

# %% [markdown]
# ## cek label (parameter politik (1) dan non politik(0))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# %%
politik_reviews = df_new[(df_new["label"] == 1)]
npolitik_reviews = df_new[(df_new["label"] == 0)]
politik_reviews.head (10)
# Out:
#     Column1                                             Tweets  label  \
# 1       1.0  Majelis Hakim Pengadilan Negeri Jakarta Selata...    1.0
# 3       3.0  Sepakat atau enggak dengan penilaian BEM UI ya...    1.0
# 7       7.0  Ia mengklarifikasi pernyataan kuasa hukum Brig...    1.0
# 24     24.0  Menteri Badan Usaha Milik Negara (BUMN) Erick ...    1.0
# 31     31.0  Ganjar Pranowo berhasil meraup suara NasDem. A...    1.0
# 35     35.0  Dewan Kolonel disebut-sebut sebagai wadah bagi...    1.0
# 36     36.0  Kuasa Hukum keluarga Brigadir J, Kamaruddin Si...    1.0
# 55     55.0  Penjabat (Pj) Gubernur DKI Jakarta Heru Budi H...    1.0
# 56     56.0  Rishi Sunak menjadi PM Inggris. Karir politik ...    1.0
# 65     65.0  “Saya orang diklat. Semua kader mesti siap apa...    1.0
#
#                                                step01  \
# 1   majelis hakim pengadilan negeri jakarta selata...
# 3   sepakat atau enggak dengan penilaian bem ui ya...
# 7   ia mengklarifikasi pernyataan kuasa hukum brig...
# 24  menteri badan usaha milik negara bumn erick th...
# 31  ganjar pranowo berhasil meraup suara nasdem an...
# 35  dewan kolonel disebut sebut sebagai wadah bagi...
# 36  kuasa hukum keluarga brigadir kamaruddin siman...
# 55  penjabat pj gubernur dki jakarta heru budi har...
# 56  rishi sunak menjadi pm inggris karir politik r...
# 65  saya orang diklat semua kader mesti siap apapu...
#
#                                                tokens  \
# 1   [majelis, hakim, pengadilan, negeri, jakarta, ...
# 3   [sepakat, atau, enggak, dengan, penilaian, bem...
# 7   [ia, mengklarifikasi, pernyataan, kuasa, hukum...
# 24  [menteri, badan, usaha, milik, negara, bumn, e...
# 31  [ganjar, pranowo, berhasil, meraup, suara, nas...
# 35  [dewan, kolonel, disebut, sebut, sebagai, wada...
# 36  [kuasa, hukum, keluarga, brigadir, kamaruddin,...
# 55  [penjabat, pj, gubernur, dki, jakarta, heru, b...
# 56  [rishi, sunak, menjadi, pm, inggris, karir, po...
# 65  [saya, orang, diklat, semua, kader, mesti, sia...
#
#                                          final_tokens  \
# 1   [majelis, hakim, pengadilan, negeri, jakarta, ...
# 3   [sepakat, atau, enggak, dengan, penilaian, bem...
# 7   [ia, mengklarifikasi, pernyataan, kuasa, hukum...
# 24  [menteri, badan, usaha, milik, negara, bumn, e...
# 31  [ganjar, pranowo, berhasil, meraup, suara, nas...
# 35  [dewan, kolonel, disebut, sebut, sebagai, wada...
# 36  [kuasa, hukum, keluarga, brigadir, kamaruddin,...
# 55  [penjabat, pj, gubernur, dki, jakarta, heru, b...
# 56  [rishi, sunak, menjadi, pm, inggris, karir, po...
# 65  [saya, orang, diklat, semua, kader, mesti, sia...
#
#                                                step02  \
# 1   majelis hakim pengadilan negeri jakarta selata...
# 3   sepakat atau enggak dengan penilaian bem ui ya...
# 7   ia mengklarifikasi pernyataan kuasa hukum brig...
# 24  menteri badan usaha milik negara bumn erick th...
# 31  ganjar pranowo berhasil meraup suara nasdem an...
# 35  dewan kolonel disebut sebut sebagai wadah bagi...
# 36  kuasa hukum keluarga brigadir kamaruddin siman...
# 55  penjabat pj gubernur dki jakarta heru budi har...
# 56  rishi sunak menjadi pm inggris karir politik r...
# 65  saya orang diklat semua kader mesti siap apapu...
#
#                                         ProcessedText
# 1   majelis hakim adil negeri jakarta selatan tola...
# 3   sepakat enggak nilai bem ui bilang joko widodo...
# 7   klarifikasi nyata kuasa hukum brigadir kamarud...
# 24  menteri badan usaha milik negara bumn erick th...
# 31  ganjar pranowo hasil raup suara nasdem anies t...
# 35  dewan kolonel sebut sebut wadah dukung puan ma...
# 36  kuasa hukum keluarga brigadir kamaruddin siman...
# 55  jabat pj gubernur dki jakarta heru budi harton...
# 56  rishi sunak jadi pm inggris karir politik rish...
# 65  orang diklat semua kader mesti siap apa kata g...

# %% [markdown]
# ## Cek Politik

# %%
politik_tf_idf_vect = TfidfVectorizer(ngram_range=(1,2))
politik_tf_idf = politik_tf_idf_vect.fit_transform(politik_reviews["ProcessedText"].values)

# %%
politik_tf_idf.shape
# Out:
# (17, 407)

# %%
features = politik_tf_idf_vect.get_feature_names()

idfValues = politik_tf_idf_vect.idf_

d = dict(zip(features, 9 - idfValues))

sortedDict = sorted(d.items(), key = lambda d: d[1], reverse = True)

for i in range(100):
    print(sortedDict[i])
# Out:
# ('presiden', 6.719066154537936)
# ('jakarta', 6.495922603223725)
# ('jokowi', 6.495922603223725)
# ('bentuk', 6.2082405307719455)
# ('bilang', 6.2082405307719455)
# ('brigadir', 6.2082405307719455)
# ('brigadir kamaruddin', 6.2082405307719455)
# ('candrawathi', 6.2082405307719455)
# ('co', 6.2082405307719455)
# ('dewan', 6.2082405307719455)
# ('dpp', 6.2082405307719455)
# ('duga', 6.2082405307719455)
# ('dukung', 6.2082405307719455)
# ('ganjar', 6.2082405307719455)
# ('gubernur', 6.2082405307719455)
# ('hukum', 6.2082405307719455)
# ('inggris', 6.2082405307719455)
# ('jadi', 6.2082405307719455)
# ('joko', 6.2082405307719455)
# ('joko widodo', 6.2082405307719455)
# ('kamaruddin', 6.2082405307719455)
# ('kamaruddin simanjuntak', 6.2082405307719455)
# ('kuasa', 6.2082405307719455)
# ('kuasa hukum', 6.2082405307719455)
# ('maruf', 6.2082405307719455)
# ('me', 6.2082405307719455)
# ('menteri', 6.2082405307719455)
# ('minta', 6.2082405307719455)
# ('posisi', 6.2082405307719455)
# ('pusat', 6.2082405307719455)
# ('putri', 6.2082405307719455)
# ('putri candrawathi', 6.2082405307719455)
# ('rishi', 6.2082405307719455)
# ('rishi sunak', 6.2082405307719455)
# ('sebut', 6.2082405307719455)
# ('simanjuntak', 6.2082405307719455)
# ('sunak', 6.2082405307719455)
# ('sunak jadi', 6.2082405307719455)
# ('widodo', 6.2082405307719455)
# ('adil', 5.80277542266378)
# ('adil negeri', 5.80277542266378)
# ('amin', 5.80277542266378)
# ('amin tunai', 5.80277542266378)
# ('ancam', 5.80277542266378)
# ('ancam copot', 5.80277542266378)
# ('anies', 5.80277542266378)
# ('anies tempat', 5.80277542266378)
# ('apa', 5.80277542266378)
# ('apa kata', 5.80277542266378)
# ('atas', 5.80277542266378)
# ('atas dakwa', 5.80277542266378)
# ('badan', 5.80277542266378)
# ('badan usaha', 5.80277542266378)
# ('banding', 5.80277542266378)
# ('banding juni', 5.80277542266378)
# ('bawah', 5.80277542266378)
# ('bawah cogvaymah', 5.80277542266378)
# ('bem', 5.80277542266378)
# ('bem ui', 5.80277542266378)
# ('bentuk poster', 5.80277542266378)
# ('bentuk tegur', 5.80277542266378)
# ('berat', 5.80277542266378)
# ('berat eksepsi', 5.80277542266378)
# ('beri', 5.80277542266378)
# ('beri sanksi', 5.80277542266378)
# ('besar', 5.80277542266378)
# ('besar lima', 5.80277542266378)
# ('bicara', 5.80277542266378)
# ('bicara kena', 5.80277542266378)
# ('bilang joko', 5.80277542266378)
# ('bilang moncer', 5.80277542266378)
# ('brigadir nofrians', 5.80277542266378)
# ('budi', 5.80277542266378)
# ('budi hartono', 5.80277542266378)
# ('bumn', 5.80277542266378)
# ('bumn erick', 5.80277542266378)
# ('calon', 5.80277542266378)
# ('calon presiden', 5.80277542266378)
# ('candrawathi ikut', 5.80277542266378)
# ('candrawathi turut', 5.80277542266378)
# ('capres', 5.80277542266378)
# ('capres comy', 5.80277542266378)
# ('cepat', 5.80277542266378)
# ('cepat sebar', 5.80277542266378)
# ('coadzmnojgln', 5.80277542266378)
# ('coc', 5.80277542266378)
# ('cofpbpq', 5.80277542266378)
# ('cogvadeo', 5.80277542266378)
# ('cogvaymah', 5.80277542266378)
# ('colfsftadotd', 5.80277542266378)
# ('comdfkklpx', 5.80277542266378)
# ('comy', 5.80277542266378)
# ('copot', 5.80277542266378)
# ('copot jajar', 5.80277542266378)
# ('coprsoryd', 5.80277542266378)
# ('coqtipehsv', 5.80277542266378)
# ('coqvtnosaipk', 5.80277542266378)
# ('couiaoyhsblb', 5.80277542266378)
# ('covulkflgq', 5.80277542266378)
# ('covvdibgo', 5.80277542266378)
# C:\Users\Adam\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
# Requirement already satisfied: pillow in c:\users\adam\anaconda3\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: matplotlib in c:\users\adam\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\adam\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\adam\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\adam\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plot

# %%
def PlotWordCloud(frequency):
    worcloudPlot = WordCloud(background_color="white", width=1500, height=1000)
    worcloudPlot.generate_from_frequencies(frequencies=frequency)
    plot.figure(figsize=(15,10))
    plot.imshow(worcloudPlot, interpolation="bilinear")
    plot.axis("off")
    plot.show()

# %%
PlotWordCloud(d)

# %% [markdown]
# ## Cek non politik

# %%
npolitik_tf_idf_vect = TfidfVectorizer(ngram_range=(1,2))
npolitik_tf_idf = npolitik_tf_idf_vect.fit_transform(npolitik_reviews["ProcessedText"].values)

# %%
npolitik_tf_idf.shape
# Out:
# (81, 1513)

# %%
features = npolitik_tf_idf_vect.get_feature_names()

idfValues = npolitik_tf_idf_vect.idf_

d = dict(zip(features, 9 - idfValues))

sortedDict = sorted(d.items(), key = lambda d: d[1], reverse = True)

for i in range(100):
    print(sortedDict[i])
# Out:
# ('jadi', 5.8958658457297926)
# ('laku', 5.8958658457297926)
# ('sebut', 5.8958658457297926)
# ('orang', 5.672722294415583)
# ('co', 5.53919090179106)
# ('istana', 5.385040221963802)
# ('kata', 5.385040221963802)
# ('tak', 5.385040221963802)
# ('dalam', 5.202718665169847)
# ('gagal', 5.202718665169847)
# ('kepala', 5.202718665169847)
# ('lalu', 5.202718665169847)
# ('obat', 5.202718665169847)
# ('perintah', 5.202718665169847)
# ('terobos', 5.202718665169847)
# ('terobos istana', 5.202718665169847)
# ('yang', 5.202718665169847)
# ('ada', 4.9795751138556374)
# ('aku', 4.9795751138556374)
# ('akut', 4.9795751138556374)
# ('alami', 4.9795751138556374)
# ('bakar', 4.9795751138556374)
# ('bawa', 4.9795751138556374)
# ('beberapa', 4.9795751138556374)
# ('bpom', 4.9795751138556374)
# ('diri', 4.9795751138556374)
# ('duga', 4.9795751138556374)
# ('gagal ginjal', 4.9795751138556374)
# ('ginjal', 4.9795751138556374)
# ('ginjal akut', 4.9795751138556374)
# ('guna', 4.9795751138556374)
# ('indonesia', 4.9795751138556374)
# ('insiden', 4.9795751138556374)
# ('istana negara', 4.9795751138556374)
# ('jakarta', 4.9795751138556374)
# ('joko', 4.9795751138556374)
# ('kali', 4.9795751138556374)
# ('kini', 4.9795751138556374)
# ('kupang', 4.9795751138556374)
# ('masuk', 4.9795751138556374)
# ('negara', 4.9795751138556374)
# ('para', 4.9795751138556374)
# ('penny', 4.9795751138556374)
# ('perempuan', 4.9795751138556374)
# ('pihak', 4.9795751138556374)
# ('polisi', 4.9795751138556374)
# ('produk', 4.9795751138556374)
# ('sama', 4.9795751138556374)
# ('sempat', 4.9795751138556374)
# ('serang', 4.9795751138556374)
# ('tahan', 4.9795751138556374)
# ('tahun', 4.9795751138556374)
# ('tarung', 4.9795751138556374)
# ('temu', 4.9795751138556374)
# ('tindak', 4.9795751138556374)
# ('acara', 4.691893041403857)
# ('air', 4.691893041403857)
# ('akibat', 4.691893041403857)
# ('aku jadi', 4.691893041403857)
# ('akun', 4.691893041403857)
# ('aman', 4.691893041403857)
# ('anggap', 4.691893041403857)
# ('anggota', 4.691893041403857)
# ('antar', 4.691893041403857)
# ('anwar', 4.691893041403857)
# ('apa', 4.691893041403857)
# ('api', 4.691893041403857)
# ('atur', 4.691893041403857)
# ('bakar senin', 4.691893041403857)
# ('banyak', 4.691893041403857)
# ('barang', 4.691893041403857)
# ('bisa', 4.691893041403857)
# ('bpom penny', 4.691893041403857)
# ('candrawathi', 4.691893041403857)
# ('candrawathi febri', 4.691893041403857)
# ('cantika', 4.691893041403857)
# ('capai', 4.691893041403857)
# ('cari', 4.691893041403857)
# ('cepat', 4.691893041403857)
# ('coba', 4.691893041403857)
# ('cukup', 4.691893041403857)
# ('dapat', 4.691893041403857)
# ('down', 4.691893041403857)
# ('dunia', 4.691893041403857)
# ('febri', 4.691893041403857)
# ('glikol', 4.691893041403857)
# ('hingga', 4.691893041403857)
# ('hukum', 4.691893041403857)
# ('jalan', 4.691893041403857)
# ('jeka', 4.691893041403857)
# ('jeka saragih', 4.691893041403857)
# ('joko anwar', 4.691893041403857)
# ('jokoanwar', 4.691893041403857)
# ('jumlah', 4.691893041403857)
# ('kait', 4.691893041403857)
# ('kalian', 4.691893041403857)
# ('kapal', 4.691893041403857)
# ('kasus', 4.691893041403857)
# ('kembang', 4.691893041403857)
# ('kemenkes', 4.691893041403857)

# %%
def PlotWordCloud(frequency):
    worcloudPlot = WordCloud(background_color="white", width=1500, height=1000)
    worcloudPlot.generate_from_frequencies(frequencies=frequency)
    plot.figure(figsize=(15,10))
    plot.imshow(worcloudPlot, interpolation="bilinear")
    plot.axis("off")
    plot.show()

# %%
PlotWordCloud(d)

# %% [markdown]
# ## Cek emosi semua label

# %%
tfidf_vect = TfidfVectorizer(ngram_range = (1,2))

# %%
Data_TFIDF = tfidf_vect.fit_transform(df_new["ProcessedText"].values)

# %%
Data_TFIDF.shape
# Out:
# (98, 1848)

# %% [markdown]
# ## Training dan testing data 70-30

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.model_selection import train_test_split

# %%
train_TFIDF, test_TFIDF, train_labels_TFIDF, test_labels_TFIDF = train_test_split(dataset_feature,dataset_label,test_size = 0.3, random_state=42)

# %%
train_TFIDF.shape, test_TFIDF.shape, train_labels_TFIDF.shape, test_labels_TFIDF.shape
# Out:
# ((68,), (30,), (68,), (30,))

# %% [markdown]
# ## Model Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
classifier_nb = Pipeline ([
    ('tfidf', TfidfVectorizer ()),
    ('model', MultinomialNB ()),
])

# %%
parameters_nb = {
    'tfidf__ngram_range' : [(1,1), (1,2), (1,3), (1,4)],
    'model__alpha' : (0.0001, 0.001, 0.1, 1, 10, 100)
}

# %%
classifier_nb = GridSearchCV(classifier_nb, parameters_nb, cv = 3, n_jobs=-1)

# %%
classifier_nb.fit(train_TFIDF, train_labels_TFIDF.ravel())
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                        ('model', MultinomialNB())]),
#              n_jobs=-1,
#              param_grid={'model__alpha': (0.0001, 0.001, 0.1, 1, 10, 100),
#                          'tfidf__ngram_range': [(1, 1), (1, 2), (1, 3),
#                                                 (1, 4)]})

# %%
y_pred_nb_train = classifier_nb.predict(train_TFIDF)
accuracy_nb_train = accuracy_score(train_labels_TFIDF, y_pred_nb_train)
print("Accuracy Training set: ", accuracy_nb_train)

y_pred_nb_test = classifier_nb.predict(test_TFIDF)
accuracy_nb_test = accuracy_score(test_labels_TFIDF, y_pred_nb_test)
print("Accuracy Test set: ", accuracy_nb_test)
# Out:
# Accuracy Training set:  0.8676470588235294
# Accuracy Test set:  0.8666666666666667

# %%
recall_nb_train = recall_score(train_labels_TFIDF, y_pred_nb_train, average='weighted')
print("Recall Training set: ", recall_nb_train)

recall_nb_test = recall_score(test_labels_TFIDF, y_pred_nb_test, average='weighted')
print("Recall Test set: ", recall_nb_test)
# Out:
# Recall Training set:  0.8676470588235294
# Recall Test set:  0.8666666666666667

# %%
precision_nb_train = precision_score(train_labels_TFIDF, y_pred_nb_train, average='weighted')
print("Precision Training set: ", precision_nb_train)

precision_nb_test = precision_score(test_labels_TFIDF, y_pred_nb_test, average='weighted')
print("Precision Test set: ", precision_nb_test)
# Out:
# Precision Training set:  0.8862591911764706
# Precision Test set:  0.7511111111111112
# C:\Users\Adam\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(test_labels_TFIDF, y_pred_nb_test), annot=True, cmap = 'viridis', fmt='.0f')
plt.xlabel("Predicted values", fontdict = {'size':14}, labelpad = 10)
plt.ylabel("Actual values"   , fontdict = {'size':14}, labelpad = 10)
plt.title ("Confusion Matrix", fontdict = {'size':18}, pad = 20)
plt.show()

# %% [markdown]
# ## Visualisasi

# %%
models = [
          ('Naive Bayes Multinomial', accuracy_nb_train, accuracy_nb_test),                    
         ]

# %%
predict = pd.DataFrame(data = models, columns=['Model', 'Training Accuracy', 'Test Accuracy'])
predict
# Out:
#                      Model  Training Accuracy  Test Accuracy
# 0  Naive Bayes Multinomial           0.867647       0.866667

# %%
models_comparison = [
                        ('Naive Bayes Multinomial', accuracy_nb_test, recall_nb_test, precision_nb_test),                          
                    ]

# %%
comparison = pd.DataFrame(data = models_comparison, columns=['Model', 'Accuracy', 'Recall', 'Precision'])
comparison
# Out:
#                      Model  Accuracy    Recall  Precision
# 0  Naive Bayes Multinomial  0.866667  0.866667   0.751111

# %%
import numpy as np

f, axes = plt.subplots(2,1, figsize=(14,10))

predict.sort_values(by=['Training Accuracy'], ascending=False, inplace=True)

sns.barplot(x='Training Accuracy', y='Model', data = predict, palette='Blues_d', ax = axes[0])
#axes[0].set(xlabel='Region', ylabel='Charges')
axes[0].set_xlabel('Training Accuracy', size=16)
axes[0].set_ylabel('Model')
axes[0].set_xlim(0,1.0)
axes[0].set_xticks(np.arange(0, 1.1, 0.1))

predict.sort_values(by=['Test Accuracy'], ascending=False, inplace=True)

sns.barplot(x='Test Accuracy', y='Model', data = predict, palette='Greens_d', ax = axes[1])
#axes[0].set(xlabel='Region', ylabel='Charges')
axes[1].set_xlabel('Test Accuracy', size=16)
axes[1].set_ylabel('Model')
axes[1].set_xlim(0,1.0)
axes[1].set_xticks(np.arange(0, 1.1, 0.1))

plt.show()

# %% [markdown]
# ## Kesimpulan
